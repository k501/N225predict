# %% [markdown]
# ## ニューラルネットワーク
# 隠れ層のレイヤーを2個増やしてみた

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import multivariate_normal, permutation
import pandas as pd
from pandas import DataFrame, Series
from sklearn.model_selection import train_test_split

np.random.seed(20160614)
tf.set_random_seed(20160614)

# %%
#snssns..set_styleset_sty ('whitegrid')
# %matplotlib inline

pd.set_option("display.max_columns", 200) # 表示カラムの最大値
pd.set_option('display.max_rows', 200) # 表示行数の最大値
pd.set_option('display.max_colwidth', 30)
pd.set_option("display.float_format", '{:.3f}'.format) # 小数点以下の有効数字

# jupyterの幅を自動調整
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# ### データ読み込み

# %%
df = pd.read_csv('../01.data/02.train/data_2013_2017.csv', index_col=0)

# %%
# 学習データと検証データに分割
X_train, X_valid, y_train, y_valid = train_test_split(df.iloc[:, 1:df.shape[1]], 
                                                    df['target'], 
                                                    test_size=0.3, 
                                                    random_state=100)
# TensorFlow用に変換
X_train = X_train.as_matrix()
y_train = y_train.as_matrix().reshape([len(y_train), 1])
X_valid = X_valid.as_matrix()
y_valid = y_valid.as_matrix().reshape([len(y_valid), 1])

# %%
# 学習データと検証データの正解含有率とレコード件数
print ('train data || Correct Data Rate : %f, Length of data: %i' % (y_train.sum()/len(y_train), len(y_train)))
print ('valid data || Correct Data Rate : %f, Length of data: %i' % (y_valid.sum()/len(y_valid), len(y_valid)))
# Out:
# train data || Correct Data Rate : 0.175234, Length of data: 856
# valid data || Correct Data Rate : 0.185286, Length of data: 367

# %% [markdown]
# ### パラメータ

# %%
# make results reproducible
seed = 3
np.random.seed(seed)
tf.set_random_seed(seed)

#  説明変数の数
NUM_VARS = X_train.shape[1]

# 学習率
LEARNING_RATE = 0.0001

# 投資判断しきい値（accuracyの算出で利用）
INVEST_THRESHOLD = 0.5

# バッチサイズ
batch_size = 100

# %%
# 説明変数
x = tf.placeholder(shape=[None, NUM_VARS], dtype=tf.float32)
#目的変数
y = tf.placeholder(shape=[None,1], dtype=tf.float32)

# %%
 # 隠れ層１のユニット数
NUM_UNITS_1 = 50
# 隠れ層２のユニット数
NUM_UNITS_2 = 25
# 隠れ層3のユニット数
NUM_UNITS_3 = 2

# バイアスの初期値に利用する
mult = X_train.flatten().mean() 

# 隠れ層１を定義
w1 = tf.Variable(tf.truncated_normal([NUM_VARS, NUM_UNITS_1]))
b1 = tf.Variable(tf.zeros([NUM_UNITS_1]))
hidden1 = tf.nn.relu(tf.matmul(x, w1) + b1*mult)

# 隠れ層2を定義
w2 = tf.Variable(tf.truncated_normal([NUM_UNITS_1, NUM_UNITS_2]))
b2 = tf.Variable(tf.zeros([NUM_UNITS_2]))
hidden2 = tf.nn.relu(tf.matmul(hidden1, w2) + b2*mult)

# 隠れ層3を定義
w3 = tf.Variable(tf.truncated_normal([NUM_UNITS_2, NUM_UNITS_3]))
b3 = tf.Variable(tf.zeros([NUM_UNITS_3]))
hidden3 = tf.nn.relu(tf.matmul(hidden2, w3) + b3*mult)

# 出力層を定義
w0 = tf.Variable(tf.zeros([NUM_UNITS_3, 1]))
b0 = tf.Variable(tf.zeros([1]))
p = tf.nn.sigmoid(tf.matmul(hidden3, w0) + b0*mult)

# %% [markdown]
# **[SNE-05]** 誤差関数 loss、トレーニングアルゴリズム train_step、正解率 accuracy を定義します。

# %%
# 誤差関数  クロスエントロピー
loss = -tf.reduce_sum(y*tf.log(p) + (1-y)*tf.log(1-p))
# トレーニングアルゴリズム
train_step = tf.train.GradientDescentOptimizer(LEARNING_RATE).minimize(loss)
# 正解率
correct_prediction = tf.equal(tf.sign(p-INVEST_THRESHOLD), tf.sign(y-INVEST_THRESHOLD))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %% [markdown]
# ### 学習

# %%
sess = tf.Session()

# %%
# 変数の初期化
init = tf.global_variables_initializer()
sess.run(init)

saver = tf.train.Saver()
#cwd = os.getcwd() # Windowsのときに必要

i = 0
loss_vec_train = []
loss_vec_valid = []
acc_vec_train = []
acc_vec_valid = []

for _ in range(20000):
    i += 1
    
    batch_index = np.random.choice(len(X_train),  size=batch_size)
    random_X_train = X_train[batch_index]
    random_y_train = y_train[batch_index]
    
    sess.run(train_step, feed_dict={x: random_X_train, y: random_y_train})

    if i % 10 == 0:
        #　トレーニングセットの損失値を保存
        loss_val, acc_val  = sess.run( [loss, accuracy], feed_dict={x: random_X_train, y: random_y_train})
        
        loss_vec_train.append(loss_val / len(random_y_train))   
        acc_vec_train.append(acc_val)
        
        # テストセットの損失値を保存
        loss_val, acc_val = sess.run( [loss, accuracy],  feed_dict={x: X_valid, y: y_valid})
        
        loss_vec_valid.append(loss_val / len(y_valid))
        acc_vec_valid.append(acc_val)

    if i % 100 == 0:
        loss_val_train, acc_val_train = sess.run( [loss, accuracy], feed_dict={x: random_X_train, y: random_y_train})
        loss_val_valid, acc_val_valid = sess.run( [loss, accuracy], feed_dict={x: X_valid, y: y_valid})
        
        print ('step: %d, train loss: %f,  train accuracy: %f,  , valid loss: %f, valid accuracy: %f' % (i, 
                                                                                                         loss_val_train / len(random_y_train), 
                                                                                                         acc_val_train, 
                                                                                                         loss_val_valid / len(y_valid), 
                                                                                                         acc_val_valid))
    
saver.save(sess, './01.saved_model/model.ckpt')
# Out:
# step: 100, train loss: 0.621333,  train accuracy: 0.760000,  , valid loss: 0.587823, valid accuracy: 0.790191
# step: 200, train loss: 0.518534,  train accuracy: 0.810000,  , valid loss: 0.509965, valid accuracy: 0.806540
# step: 300, train loss: 0.513254,  train accuracy: 0.810000,  , valid loss: 0.505752, valid accuracy: 0.803815
# step: 400, train loss: 0.584462,  train accuracy: 0.760000,  , valid loss: 0.539883, valid accuracy: 0.782016
# step: 500, train loss: 0.602624,  train accuracy: 0.690000,  , valid loss: 0.570310, valid accuracy: 0.760218
# step: 600, train loss: 0.522626,  train accuracy: 0.790000,  , valid loss: 0.493563, valid accuracy: 0.809264
# step: 700, train loss: 0.493845,  train accuracy: 0.820000,  , valid loss: 0.485072, valid accuracy: 0.814714
# step: 800, train loss: 0.573746,  train accuracy: 0.770000,  , valid loss: 0.525858, valid accuracy: 0.814714
# step: 900, train loss: 0.520755,  train accuracy: 0.800000,  , valid loss: 0.487756, valid accuracy: 0.809264
# step: 1000, train loss: 0.525498,  train accuracy: 0.790000,  , valid loss: 0.488119, valid accuracy: 0.814714
# step: 18000, train loss: 0.387311,  train accuracy: 0.850000,  , valid loss: 0.558053, valid accuracy: 0.806540
# step: 18100, train loss: 0.336363,  train accuracy: 0.870000,  , valid loss: 0.561096, valid accuracy: 0.798365
# step: 18200, train loss: 0.319635,  train accuracy: 0.880000,  , valid loss: 0.563383, valid accuracy: 0.803815
# step: 18300, train loss: 0.380775,  train accuracy: 0.850000,  , valid loss: 0.568645, valid accuracy: 0.803815
# step: 18400, train loss: 0.312040,  train accuracy: 0.890000,  , valid loss: 0.563033, valid accuracy: 0.801090
# step: 18500, train loss: 0.402697,  train accuracy: 0.790000,  , valid loss: 0.553644, valid accuracy: 0.798365
# step: 18600, train loss: 0.478215,  train accuracy: 0.770000,  , valid loss: 0.555300, valid accuracy: 0.798365
# step: 18700, train loss: 0.366790,  train accuracy: 0.810000,  , valid loss: 0.566923, valid accuracy: 0.801090
# step: 18800, train loss: 0.396689,  train accuracy: 0.830000,  , valid loss: 0.570652, valid accuracy: 0.803815
# step: 18900, train loss: 0.294566,  train accuracy: 0.910000,  , valid loss: 0.568078, valid accuracy: 0.801090
# step: 19000, train loss: 0.454629,  train accuracy: 0.810000,  , valid loss: 0.572188, valid accuracy: 0.798365
# step: 19100, train loss: 0.420637,  train accuracy: 0.770000,  , valid loss: 0.576375, valid accuracy: 0.803815
# step: 19200, train loss: 0.389190,  train accuracy: 0.840000,  , valid loss: 0.582653, valid accuracy: 0.803815
# step: 19300, train loss: 0.414966,  train accuracy: 0.820000,  , valid loss: 0.586002, valid accuracy: 0.798365
# step: 19400, train loss: 0.306861,  train accuracy: 0.880000,  , valid loss: 0.575391, valid accuracy: 0.809264
# step: 19500, train loss: 0.278774,  train accuracy: 0.890000,  , valid loss: 0.584983, valid accuracy: 0.801090
# step: 19600, train loss: 0.293813,  train accuracy: 0.880000,  , valid loss: 0.588445, valid accuracy: 0.795640
# step: 19700, train loss: 0.366542,  train accuracy: 0.860000,  , valid loss: 0.590602, valid accuracy: 0.801090
# step: 19800, train loss: 0.329675,  train accuracy: 0.850000,  , valid loss: 0.588286, valid accuracy: 0.798365
# step: 19900, train loss: 0.345877,  train accuracy: 0.860000,  , valid loss: 0.590087, valid accuracy: 0.801090
# step: 20000, train loss: 0.306953,  train accuracy: 0.850000,  , valid loss: 0.593635, valid accuracy: 0.803815
# './01.saved_model/model.ckpt'

# %%
fig = plt.figure(figsize=(18, 5))
ax = plt.subplot()

plt.plot(loss_vec_train,   label='batch loss')
plt.plot(loss_vec_valid,  'r--',  label='valid loss' )
plt.title('Log Loss per Generation')

ax.grid() #グリッド表示
fig.autofmt_xdate() #x軸のオートフォーマット
plt.legend() # 凡例の表示
#plt.savefig('ssss.png')
plt.show()

# %%
fig = plt.figure(figsize=(18, 5))
ax = plt.subplot()

plt.plot(acc_vec_train,   label='train loss')
plt.plot(acc_vec_valid,  'r--',  label='valid loss' )
plt.title('Accuracy per Generation')

ax.grid() #グリッド表示
fig.autofmt_xdate() #x軸のオートフォーマット
plt.legend() # 凡例の表示
#plt.savefig('ssss.png')
plt.show()
