# %% [markdown]
# ## ニューラルネットワーク
# 隠れ層のレイヤーを１個増やしてみた

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import multivariate_normal, permutation
import pandas as pd
from pandas import DataFrame, Series
from sklearn.model_selection import train_test_split

np.random.seed(20160614)
tf.set_random_seed(20160614)

# %%
#snssns..set_styleset_sty ('whitegrid')
# %matplotlib inline

pd.set_option("display.max_columns", 200) # 表示カラムの最大値
pd.set_option('display.max_rows', 200) # 表示行数の最大値
pd.set_option('display.max_colwidth', 30)
pd.set_option("display.float_format", '{:.3f}'.format) # 小数点以下の有効数字

# jupyterの幅を自動調整
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# ### データ読み込み

# %%
df = pd.read_csv('../01.data/02.train/data_2013_2017.csv', index_col=0)

# %%
# 学習データと検証データに分割
X_train, X_valid, y_train, y_valid = train_test_split(df.iloc[:, 1:df.shape[1]], 
                                                    df['target'], 
                                                    test_size=0.3, 
                                                    random_state=100)
# TensorFlow用に変換
X_train = X_train.as_matrix()
y_train = y_train.as_matrix().reshape([len(y_train), 1])
X_valid = X_valid.as_matrix()
y_valid = y_valid.as_matrix().reshape([len(y_valid), 1])

# %%
# 学習データと検証データの正解含有率とレコード件数
print ('train data || Correct Data Rate : %f, Length of data: %i' % (y_train.sum()/len(y_train), len(y_train)))
print ('valid data || Correct Data Rate : %f, Length of data: %i' % (y_valid.sum()/len(y_valid), len(y_valid)))
# Out:
# train data || Correct Data Rate : 0.175234, Length of data: 856
# valid data || Correct Data Rate : 0.185286, Length of data: 367

# %% [markdown]
# ### パラメータ

# %%
# make results reproducible
seed = 3
np.random.seed(seed)
tf.set_random_seed(seed)

#  説明変数の数
NUM_VARS = X_train.shape[1]

# 学習率
LEARNING_RATE = 0.0002

# 投資判断しきい値（accuracyの算出で利用）
INVEST_THRESHOLD = 0.5

# バッチサイズ
batch_size = 100

# %%
# 説明変数
x = tf.placeholder(shape=[None, NUM_VARS], dtype=tf.float32)
#目的変数
y = tf.placeholder(shape=[None,1], dtype=tf.float32)

# %%
 # 隠れ層１のユニット数
NUM_UNITS_1 = 5
 # 隠れ層２のユニット数
NUM_UNITS_2 = 4

# バイアスの初期値に利用する
mult = X_train.flatten().mean() 

# 隠れ層１を定義
w1 = tf.Variable(tf.truncated_normal([NUM_VARS, NUM_UNITS_1]))
b1 = tf.Variable(tf.zeros([NUM_UNITS_1]))
#hidden1 = tf.nn.tanh(tf.matmul(x, w1) + b1*mult)
hidden1 = tf.nn.relu(tf.matmul(x, w1) + b1*mult)

# 隠れ層2を定義
w2 = tf.Variable(tf.truncated_normal([NUM_UNITS_1, NUM_UNITS_2]))
b2 = tf.Variable(tf.zeros([NUM_UNITS_2]))
#hidden2 = tf.nn.tanh(tf.matmul(hidden1, w2) + b2*mult)
hidden2 = tf.nn.relu(tf.matmul(hidden1, w2) + b2*mult)

# 出力層を定義
w0 = tf.Variable(tf.zeros([NUM_UNITS_2, 1]))
b0 = tf.Variable(tf.zeros([1]))
p = tf.nn.sigmoid(tf.matmul(hidden2, w0) + b0*mult)

# %% [markdown]
# **[SNE-05]** 誤差関数 loss、トレーニングアルゴリズム train_step、正解率 accuracy を定義します。

# %%
# 誤差関数  クロスエントロピー
loss = -tf.reduce_sum(y*tf.log(p) + (1-y)*tf.log(1-p))
# トレーニングアルゴリズム
train_step = tf.train.GradientDescentOptimizer(LEARNING_RATE).minimize(loss)
# 正解率
correct_prediction = tf.equal(tf.sign(p-INVEST_THRESHOLD), tf.sign(y-INVEST_THRESHOLD))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %% [markdown]
# ### 学習

# %%
sess = tf.Session()

# %%
# 変数の初期化
init = tf.global_variables_initializer()
sess.run(init)

saver = tf.train.Saver()

#cwd = os.getcwd() # Windowsのときに必要

i = 0
loss_vec_train = []
loss_vec_valid = []
acc_vec_train = []
acc_vec_valid = []

for _ in range(10000):
    i += 1
    
    batch_index = np.random.choice(len(X_train),  size=batch_size)
    random_X_train = X_train[batch_index]
    random_y_train = y_train[batch_index]
    
    sess.run(train_step, feed_dict={x: random_X_train, y: random_y_train})

    if i % 10 == 0:
        #　トレーニングセットの損失値を保存
        loss_val, acc_val  = sess.run( [loss, accuracy], feed_dict={x: random_X_train, y: random_y_train})
        
        loss_vec_train.append(loss_val / len(random_y_train))   
        acc_vec_train.append(acc_val)
        
        # テストセットの損失値を保存
        loss_val, acc_val = sess.run( [loss, accuracy],  feed_dict={x: X_valid, y: y_valid})
        
        loss_vec_valid.append(loss_val / len(y_valid))
        acc_vec_valid.append(acc_val)

    if i % 100 == 0:
        loss_val_train, acc_val_train = sess.run( [loss, accuracy], feed_dict={x: random_X_train, y: random_y_train})
        loss_val_valid, acc_val_valid = sess.run( [loss, accuracy], feed_dict={x: X_valid, y: y_valid})
        
        print ('step: %d, train loss: %f,  train accuracy: %f,  , valid loss: %f, valid accuracy: %f' % (i, 
                                                                                                         loss_val_train / len(random_y_train), 
                                                                                                         acc_val_train, 
                                                                                                         loss_val_valid / len(y_valid), 
                                                                                                         acc_val_valid))
    
saver.save(sess, './01.saved_model/model.ckpt')
# Out:
# step: 100, train loss: 0.452100,  train accuracy: 0.840000,  , valid loss: 0.486791, valid accuracy: 0.814714
# step: 200, train loss: 0.409085,  train accuracy: 0.860000,  , valid loss: 0.487317, valid accuracy: 0.814714
# step: 300, train loss: 0.508880,  train accuracy: 0.790000,  , valid loss: 0.488642, valid accuracy: 0.814714
# step: 400, train loss: 0.584100,  train accuracy: 0.750000,  , valid loss: 0.484359, valid accuracy: 0.814714
# step: 500, train loss: 0.450548,  train accuracy: 0.850000,  , valid loss: 0.486432, valid accuracy: 0.814714
# step: 600, train loss: 0.485125,  train accuracy: 0.800000,  , valid loss: 0.484119, valid accuracy: 0.814714
# step: 700, train loss: 0.451800,  train accuracy: 0.820000,  , valid loss: 0.487890, valid accuracy: 0.814714
# step: 800, train loss: 0.514641,  train accuracy: 0.800000,  , valid loss: 0.483742, valid accuracy: 0.814714
# step: 900, train loss: 0.356128,  train accuracy: 0.890000,  , valid loss: 0.486112, valid accuracy: 0.814714
# step: 1000, train loss: 0.472250,  train accuracy: 0.810000,  , valid loss: 0.483776, valid accuracy: 0.814714
# step: 1100, train loss: 0.379995,  train accuracy: 0.890000,  , valid loss: 0.494763, valid accuracy: 0.814714
# step: 1200, train loss: 0.508176,  train accuracy: 0.800000,  , valid loss: 0.485619, valid accuracy: 0.814714
# step: 1300, train loss: 0.429429,  train accuracy: 0.840000,  , valid loss: 0.485065, valid accuracy: 0.814714
# step: 1400, train loss: 0.443697,  train accuracy: 0.840000,  , valid loss: 0.488245, valid accuracy: 0.814714
# step: 1500, train loss: 0.337985,  train accuracy: 0.890000,  , valid loss: 0.491801, valid accuracy: 0.814714
# step: 1600, train loss: 0.586260,  train accuracy: 0.750000,  , valid loss: 0.486523, valid accuracy: 0.814714
# step: 1700, train loss: 0.531682,  train accuracy: 0.780000,  , valid loss: 0.483842, valid accuracy: 0.814714
# step: 1800, train loss: 0.353600,  train accuracy: 0.890000,  , valid loss: 0.486624, valid accuracy: 0.814714
# step: 1900, train loss: 0.490996,  train accuracy: 0.790000,  , valid loss: 0.484940, valid accuracy: 0.814714
# step: 2000, train loss: 0.467350,  train accuracy: 0.830000,  , valid loss: 0.485851, valid accuracy: 0.814714
# step: 2100, train loss: 0.386774,  train accuracy: 0.870000,  , valid loss: 0.485972, valid accuracy: 0.814714
# step: 2200, train loss: 0.512735,  train accuracy: 0.790000,  , valid loss: 0.482713, valid accuracy: 0.814714
# step: 2300, train loss: 0.454425,  train accuracy: 0.820000,  , valid loss: 0.483575, valid accuracy: 0.814714
# step: 2400, train loss: 0.415046,  train accuracy: 0.840000,  , valid loss: 0.485876, valid accuracy: 0.814714
# step: 2500, train loss: 0.486572,  train accuracy: 0.830000,  , valid loss: 0.485078, valid accuracy: 0.814714
# step: 2600, train loss: 0.426073,  train accuracy: 0.860000,  , valid loss: 0.486104, valid accuracy: 0.814714
# step: 2700, train loss: 0.426272,  train accuracy: 0.850000,  , valid loss: 0.486015, valid accuracy: 0.814714
# step: 2800, train loss: 0.413074,  train accuracy: 0.860000,  , valid loss: 0.483940, valid accuracy: 0.814714
# step: 2900, train loss: 0.442677,  train accuracy: 0.830000,  , valid loss: 0.483389, valid accuracy: 0.814714
# step: 3000, train loss: 0.456494,  train accuracy: 0.830000,  , valid loss: 0.483381, valid accuracy: 0.814714
# step: 3100, train loss: 0.432084,  train accuracy: 0.840000,  , valid loss: 0.484154, valid accuracy: 0.814714
# step: 3200, train loss: 0.440922,  train accuracy: 0.820000,  , valid loss: 0.483861, valid accuracy: 0.814714
# step: 3300, train loss: 0.457750,  train accuracy: 0.820000,  , valid loss: 0.486373, valid accuracy: 0.814714
# step: 3400, train loss: 0.546811,  train accuracy: 0.760000,  , valid loss: 0.481948, valid accuracy: 0.814714
# step: 3500, train loss: 0.435854,  train accuracy: 0.850000,  , valid loss: 0.481680, valid accuracy: 0.814714
# step: 3600, train loss: 0.411828,  train accuracy: 0.840000,  , valid loss: 0.486248, valid accuracy: 0.814714
# step: 3700, train loss: 0.601983,  train accuracy: 0.720000,  , valid loss: 0.482917, valid accuracy: 0.814714
# step: 3800, train loss: 0.487975,  train accuracy: 0.810000,  , valid loss: 0.483223, valid accuracy: 0.814714
# step: 3900, train loss: 0.338521,  train accuracy: 0.910000,  , valid loss: 0.495800, valid accuracy: 0.814714
# step: 4000, train loss: 0.441173,  train accuracy: 0.850000,  , valid loss: 0.481212, valid accuracy: 0.814714
# step: 4100, train loss: 0.534261,  train accuracy: 0.770000,  , valid loss: 0.481329, valid accuracy: 0.814714
# step: 4200, train loss: 0.424166,  train accuracy: 0.850000,  , valid loss: 0.482269, valid accuracy: 0.814714
# step: 4300, train loss: 0.388969,  train accuracy: 0.880000,  , valid loss: 0.486637, valid accuracy: 0.814714
# step: 4400, train loss: 0.419361,  train accuracy: 0.850000,  , valid loss: 0.483365, valid accuracy: 0.814714
# step: 4500, train loss: 0.491937,  train accuracy: 0.790000,  , valid loss: 0.481785, valid accuracy: 0.814714
# step: 4600, train loss: 0.420322,  train accuracy: 0.840000,  , valid loss: 0.485617, valid accuracy: 0.814714
# step: 4700, train loss: 0.454229,  train accuracy: 0.840000,  , valid loss: 0.484502, valid accuracy: 0.814714
# step: 4800, train loss: 0.375154,  train accuracy: 0.870000,  , valid loss: 0.486467, valid accuracy: 0.814714
# step: 4900, train loss: 0.530410,  train accuracy: 0.790000,  , valid loss: 0.480727, valid accuracy: 0.814714
# step: 5000, train loss: 0.340887,  train accuracy: 0.890000,  , valid loss: 0.490752, valid accuracy: 0.814714
# step: 5100, train loss: 0.500723,  train accuracy: 0.800000,  , valid loss: 0.482841, valid accuracy: 0.814714
# step: 5200, train loss: 0.456790,  train accuracy: 0.830000,  , valid loss: 0.481191, valid accuracy: 0.814714
# step: 5300, train loss: 0.476534,  train accuracy: 0.800000,  , valid loss: 0.480446, valid accuracy: 0.814714
# step: 5400, train loss: 0.447564,  train accuracy: 0.830000,  , valid loss: 0.482218, valid accuracy: 0.814714
# step: 5500, train loss: 0.374621,  train accuracy: 0.890000,  , valid loss: 0.483262, valid accuracy: 0.814714
# step: 5600, train loss: 0.342347,  train accuracy: 0.900000,  , valid loss: 0.493062, valid accuracy: 0.814714
# step: 5700, train loss: 0.483190,  train accuracy: 0.810000,  , valid loss: 0.480181, valid accuracy: 0.814714
# step: 5800, train loss: 0.636484,  train accuracy: 0.700000,  , valid loss: 0.481208, valid accuracy: 0.814714
# step: 5900, train loss: 0.412757,  train accuracy: 0.860000,  , valid loss: 0.483837, valid accuracy: 0.814714
# step: 6000, train loss: 0.469022,  train accuracy: 0.830000,  , valid loss: 0.482225, valid accuracy: 0.814714
# step: 6100, train loss: 0.432868,  train accuracy: 0.830000,  , valid loss: 0.483855, valid accuracy: 0.814714
# step: 6200, train loss: 0.408853,  train accuracy: 0.850000,  , valid loss: 0.482343, valid accuracy: 0.814714
# step: 6300, train loss: 0.457440,  train accuracy: 0.830000,  , valid loss: 0.480042, valid accuracy: 0.814714
# step: 6400, train loss: 0.504339,  train accuracy: 0.800000,  , valid loss: 0.479707, valid accuracy: 0.814714
# step: 6500, train loss: 0.412506,  train accuracy: 0.860000,  , valid loss: 0.483673, valid accuracy: 0.814714
# step: 6600, train loss: 0.525603,  train accuracy: 0.780000,  , valid loss: 0.481332, valid accuracy: 0.814714
# step: 6700, train loss: 0.516581,  train accuracy: 0.770000,  , valid loss: 0.479615, valid accuracy: 0.814714
# step: 6800, train loss: 0.503498,  train accuracy: 0.790000,  , valid loss: 0.479807, valid accuracy: 0.814714
# step: 6900, train loss: 0.456054,  train accuracy: 0.820000,  , valid loss: 0.481728, valid accuracy: 0.814714
# step: 7000, train loss: 0.405589,  train accuracy: 0.850000,  , valid loss: 0.481715, valid accuracy: 0.814714
# step: 7100, train loss: 0.477194,  train accuracy: 0.790000,  , valid loss: 0.480204, valid accuracy: 0.814714
# step: 7200, train loss: 0.413944,  train accuracy: 0.850000,  , valid loss: 0.481486, valid accuracy: 0.814714
# step: 7300, train loss: 0.412139,  train accuracy: 0.870000,  , valid loss: 0.479577, valid accuracy: 0.814714
# step: 7400, train loss: 0.473778,  train accuracy: 0.810000,  , valid loss: 0.479083, valid accuracy: 0.814714
# step: 7500, train loss: 0.447257,  train accuracy: 0.830000,  , valid loss: 0.481167, valid accuracy: 0.814714
# step: 7600, train loss: 0.393048,  train accuracy: 0.860000,  , valid loss: 0.481977, valid accuracy: 0.814714
# step: 7700, train loss: 0.425414,  train accuracy: 0.840000,  , valid loss: 0.481870, valid accuracy: 0.814714
# step: 7800, train loss: 0.372865,  train accuracy: 0.880000,  , valid loss: 0.480572, valid accuracy: 0.814714
# step: 7900, train loss: 0.494538,  train accuracy: 0.810000,  , valid loss: 0.479881, valid accuracy: 0.814714
# step: 8000, train loss: 0.518897,  train accuracy: 0.780000,  , valid loss: 0.478822, valid accuracy: 0.814714
# step: 8100, train loss: 0.524709,  train accuracy: 0.790000,  , valid loss: 0.478864, valid accuracy: 0.814714
# step: 8200, train loss: 0.425570,  train accuracy: 0.850000,  , valid loss: 0.479125, valid accuracy: 0.814714
# step: 8300, train loss: 0.490028,  train accuracy: 0.810000,  , valid loss: 0.478721, valid accuracy: 0.814714
# step: 8400, train loss: 0.388598,  train accuracy: 0.850000,  , valid loss: 0.485358, valid accuracy: 0.814714
# step: 8500, train loss: 0.418830,  train accuracy: 0.850000,  , valid loss: 0.484339, valid accuracy: 0.814714
# step: 8600, train loss: 0.428337,  train accuracy: 0.840000,  , valid loss: 0.481731, valid accuracy: 0.814714
# step: 8700, train loss: 0.510149,  train accuracy: 0.790000,  , valid loss: 0.481306, valid accuracy: 0.814714
# step: 8800, train loss: 0.461372,  train accuracy: 0.820000,  , valid loss: 0.478434, valid accuracy: 0.814714
# step: 8900, train loss: 0.390464,  train accuracy: 0.850000,  , valid loss: 0.479952, valid accuracy: 0.814714
# step: 9000, train loss: 0.433810,  train accuracy: 0.840000,  , valid loss: 0.478444, valid accuracy: 0.814714
# step: 9100, train loss: 0.474746,  train accuracy: 0.820000,  , valid loss: 0.480594, valid accuracy: 0.814714
# step: 9200, train loss: 0.520832,  train accuracy: 0.800000,  , valid loss: 0.479085, valid accuracy: 0.814714
# step: 9300, train loss: 0.403588,  train accuracy: 0.860000,  , valid loss: 0.486827, valid accuracy: 0.814714
# step: 9400, train loss: 0.426294,  train accuracy: 0.860000,  , valid loss: 0.480487, valid accuracy: 0.814714
# step: 9500, train loss: 0.392236,  train accuracy: 0.860000,  , valid loss: 0.479540, valid accuracy: 0.814714
# step: 9600, train loss: 0.411818,  train accuracy: 0.850000,  , valid loss: 0.484094, valid accuracy: 0.814714
# step: 9700, train loss: 0.393662,  train accuracy: 0.850000,  , valid loss: 0.484785, valid accuracy: 0.814714
# step: 9800, train loss: 0.361007,  train accuracy: 0.880000,  , valid loss: 0.481681, valid accuracy: 0.814714
# step: 9900, train loss: 0.413391,  train accuracy: 0.850000,  , valid loss: 0.480871, valid accuracy: 0.814714
# step: 10000, train loss: 0.487734,  train accuracy: 0.800000,  , valid loss: 0.478924, valid accuracy: 0.814714
# './01.saved_model/model.ckpt'

# %%
fig = plt.figure(figsize=(18, 5))
ax = plt.subplot()

plt.plot(loss_vec_train,   label='batch loss')
plt.plot(loss_vec_valid,  'r--',  label='valid loss' )
plt.title('Log Loss per Generation')

ax.grid() #グリッド表示
fig.autofmt_xdate() #x軸のオートフォーマット
plt.legend() # 凡例の表示
#plt.savefig('ssss.png')
plt.show()

# %%
fig = plt.figure(figsize=(18, 5))
ax = plt.subplot()

plt.plot(acc_vec_train,   label='train loss')
plt.plot(acc_vec_valid,  'r--',  label='valid loss' )
plt.title('Accuracy per Generation')

ax.grid() #グリッド表示
fig.autofmt_xdate() #x軸のオートフォーマット
plt.legend() # 凡例の表示
#plt.savefig('ssss.png')
plt.show()

# %%
sess.run( p, feed_dict={x: X_valid, y: y_valid})
# Out:
# array([[  1.45543545e-01],
#        [  2.65906721e-01],
#        [  7.90299624e-02],
#        [  1.69611804e-03],
#        [  4.77148145e-01],
#        [  2.75266647e-01],
#        [  7.79008791e-02],
#        [  8.68320167e-02],
#        [  2.02228487e-01],
#        [  7.07714111e-02],
#        [  4.08726633e-01],
#        [  2.18399599e-01],
#        [  3.25112760e-01],
#        [  2.29705513e-01],
#        [  2.21909389e-01],
#        [  9.95068029e-02],
#        [  1.03083208e-01],
#        [  9.93293077e-02],
#        [  6.88261688e-02],
#        [  1.78958282e-01],
#        [  2.57222027e-01],
#        [  3.15507948e-01],
#        [  1.70454711e-01],
#        [  7.98099339e-02],
#        [  1.65787041e-01],
#        [  2.02536911e-01],
#        [  1.67302310e-01],
#        [  1.04483657e-01],
#        [  1.68456808e-01],
#        [  1.50417686e-01],
#        [  2.88019896e-01],
#        [  1.24114908e-01],
#        [  1.92193121e-01],
#        [  1.20946310e-01],
#        [  1.92980692e-01],
#        [  1.63613097e-03],
#        [  8.56347382e-02],
#        [  2.30490178e-01],
#        [  2.14283153e-01],
#        [  1.11144915e-01],
#        [  9.08463746e-02],
#        [  6.20048046e-02],
#        [  8.59816596e-02],
#        [  5.04032373e-01],
#        [  1.68847218e-01],
#        [  1.73800532e-02],
#        [  2.37259641e-01],
#        [  7.39424303e-02],
#        [  6.31109551e-02],
#        [  4.77148145e-01],
#        [  7.96456784e-02],
#        [  1.14969425e-02],
#        [  1.33834690e-01],
#        [  2.24323213e-01],
#        [  2.27016494e-01],
#        [  1.51194692e-01],
#        [  2.40314439e-01],
#        [  1.05021141e-01],
#        [  1.11615308e-01],
#        [  2.19684258e-01],
#        [  5.43208569e-02],
#        [  1.09056868e-01],
#        [  4.89378907e-02],
#        [  7.89607316e-02],
#        [  3.23421866e-01],
#        [  2.45597020e-01],
#        [  4.03377833e-03],
#        [  1.62040204e-01],
#        [  1.44171983e-01],
#        [  2.20733464e-01],
#        [  7.89793506e-02],
#        [  1.85550675e-01],
#        [  4.77148145e-01],
#        [  1.21211194e-01],
#        [  3.05904597e-01],
#        [  2.91889369e-01],
#        [  1.40520349e-01],
#        [  1.99363828e-01],
#        [  2.38877505e-01],
#        [  1.23812944e-01],
#        [  5.81249259e-02],
#        [  8.24000612e-02],
#        [  1.92871377e-01],
#        [  1.23159550e-01],
#        [  1.40343904e-01],
#        [  1.32561997e-02],
#        [  2.87164032e-01],
#        [  8.00489932e-02],
#        [  6.94383979e-02],
#        [  6.01623580e-02],
#        [  3.62221450e-02],
#        [  1.38993055e-01],
#        [  2.30867058e-01],
#        [  3.04707915e-01],
#        [  3.71177733e-01],
#        [  1.42368451e-01],
#        [  1.22418679e-01],
#        [  7.90222213e-02],
#        [  4.67558801e-01],
#        [  1.27365515e-01],
#        [  1.16707273e-01],
#        [  1.73135042e-01],
#        [  1.37561873e-01],
#        [  1.10263512e-01],
#        [  8.62549990e-02],
#        [  1.08738169e-01],
#        [  1.60362631e-01],
#        [  1.63534313e-01],
#        [  1.76209092e-01],
#        [  3.76081347e-01],
#        [  1.12960532e-01],
#        [  4.49229121e-01],
#        [  2.56693304e-01],
#        [  1.76032037e-01],
#        [  1.78552642e-01],
#        [  1.54984683e-01],
#        [  2.70180076e-01],
#        [  2.56908476e-01],
#        [  4.77148145e-01],
#        [  2.25647449e-01],
#        [  5.96677251e-02],
#        [  2.29345724e-01],
#        [  1.25670463e-01],
#        [  9.76560488e-02],
#        [  2.48830989e-01],
#        [  2.21148700e-01],
#        [  4.77148145e-01],
#        [  2.20191628e-02],
#        [  1.35848239e-01],
#        [  3.48982662e-01],
#        [  8.38954449e-02],
#        [  1.47147104e-01],
#        [  9.52664316e-02],
#        [  1.20276421e-01],
#        [  7.54547194e-02],
#        [  6.39501065e-02],
#        [  2.04245001e-01],
#        [  2.12434575e-01],
#        [  1.54489785e-01],
#        [  3.79288822e-01],
#        [  2.40414023e-01],
#        [  4.61398780e-01],
#        [  1.00589236e-02],
#        [  7.52438605e-02],
#        [  2.10668132e-01],
#        [  4.08704668e-01],
#        [  1.69916704e-01],
#        [  2.09583014e-01],
#        [  2.40451708e-01],
#        [  1.83374748e-01],
#        [  3.68305929e-02],
#        [  3.90031546e-01],
#        [  2.63674766e-01],
#        [  3.42698336e-01],
#        [  1.65073246e-01],
#        [  1.43058300e-01],
#        [  3.43640856e-02],
#        [  3.06899220e-01],
#        [  1.23648278e-01],
#        [  2.03985739e-02],
#        [  1.24283820e-01],
#        [  9.79169458e-02],
#        [  1.11809917e-01],
#        [  6.13802224e-02],
#        [  8.79441500e-02],
#        [  1.14755601e-01],
#        [  8.11403841e-02],
#        [  2.43278518e-01],
#        [  1.16614461e-01],
#        [  7.07322210e-02],
#        [  1.94835499e-01],
#        [  1.06570132e-01],
#        [  2.42190391e-01],
#        [  2.27971122e-01],
#        [  1.69060230e-01],
#        [  2.03939050e-01],
#        [  4.48516816e-01],
#        [  1.65921271e-01],
#        [  7.50856847e-02],
#        [  5.44596761e-02],
#        [  5.46594970e-02],
#        [  2.13201120e-01],
#        [  3.67475480e-01],
#        [  1.94070637e-01],
#        [  6.30585924e-02],
#        [  8.38213563e-02],
#        [  3.50282818e-01],
#        [  1.06802862e-02],
#        [  2.52792954e-01],
#        [  1.12983391e-01],
#        [  1.44325003e-01],
#        [  6.83975965e-02],
#        [  4.94619971e-03],
#        [  1.01069652e-01],
#        [  2.99176186e-01],
#        [  6.53574020e-02],
#        [  1.29930228e-01],
#        [  1.32580742e-01],
#        [  8.71230289e-02],
#        [  4.72887307e-02],
#        [  3.82586420e-01],
#        [  2.95687467e-02],
#        [  3.93033564e-01],
#        [  6.18513301e-02],
#        [  1.54571086e-01],
#        [  1.69742536e-02],
#        [  2.70099074e-01],
#        [  3.34952652e-01],
#        [  2.04297394e-01],
#        [  2.74072587e-01],
#        [  9.08379853e-02],
#        [  7.63568841e-03],
#        [  9.41695422e-02],
#        [  9.47130173e-02],
#        [  1.60144389e-01],
#        [  1.29531762e-02],
#        [  6.29286235e-03],
#        [  2.58101821e-01],
#        [  2.49330536e-01],
#        [  8.46214294e-02],
#        [  6.30915910e-02],
#        [  6.11584727e-03],
#        [  3.76178592e-01],
#        [  3.02879095e-01],
#        [  9.93410796e-02],
#        [  1.53540611e-01],
#        [  1.05682991e-01],
#        [  3.65193069e-01],
#        [  1.12197638e-01],
#        [  3.36169749e-01],
#        [  6.00074278e-03],
#        [  1.35758951e-01],
#        [  1.13066891e-02],
#        [  6.54280409e-02],
#        [  3.82379502e-01],
#        [  4.54021543e-02],
#        [  8.46880302e-02],
#        [  2.09352851e-01],
#        [  2.03200743e-01],
#        [  1.95733681e-01],
#        [  9.41049904e-02],
#        [  6.01762384e-02],
#        [  9.21237320e-02],
#        [  2.43740529e-01],
#        [  1.67766005e-01],
#        [  3.61132801e-01],
#        [  9.05566514e-02],
#        [  1.22163989e-01],
#        [  1.36866182e-01],
#        [  5.62121309e-02],
#        [  5.36128841e-02],
#        [  1.41396537e-01],
#        [  2.38298342e-01],
#        [  1.57640368e-01],
#        [  1.05870359e-01],
#        [  1.04057752e-02],
#        [  2.71275383e-03],
#        [  2.97617048e-01],
#        [  7.48362951e-03],
#        [  3.09704483e-01],
#        [  1.49555609e-01],
#        [  4.99893464e-02],
#        [  8.72923359e-02],
#        [  1.15275458e-01],
#        [  1.87669501e-01],
#        [  1.57024398e-01],
#        [  1.80310458e-01],
#        [  3.39423716e-02],
#        [  1.44247994e-01],
#        [  7.16501549e-02],
#        [  2.52818435e-01],
#        [  2.36850068e-01],
#        [  1.52060330e-01],
#        [  9.72501487e-02],
#        [  1.30487531e-01],
#        [  1.06980480e-01],
#        [  1.12926871e-01],
#        [  1.74324110e-01],
#        [  1.29101068e-01],
#        [  4.53818105e-02],
#        [  7.63418749e-02],
#        [  2.87076365e-03],
#        [  3.90345454e-01],
#        [  9.12971720e-02],
#        [  9.92122442e-02],
#        [  2.48926058e-01],
#        [  1.33878216e-01],
#        [  1.25405341e-01],
#        [  3.99748325e-01],
#        [  1.49838030e-01],
#        [  1.26093328e-01],
#        [  1.12790078e-01],
#        [  1.18654318e-01],
#        [  1.88700870e-01],
#        [  6.27978966e-02],
#        [  3.41039300e-01],
#        [  6.20179698e-02],
#        [  8.82620290e-02],
#        [  1.12423718e-01],
#        [  8.15854073e-02],
#        [  2.89575994e-01],
#        [  4.73890938e-02],
#        [  5.81836775e-02],
#        [  3.07799829e-03],
#        [  6.71363771e-02],
#        [  1.81168854e-01],
#        [  7.26005286e-02],
#        [  8.40776339e-02],
#        [  7.65382648e-02],
#        [  2.82999419e-04],
#        [  6.37908429e-02],
#        [  3.14256161e-01],
#        [  1.34590253e-01],
#        [  1.88454062e-01],
#        [  2.68716872e-01],
#        [  4.12902944e-02],
#        [  1.67275235e-01],
#        [  4.85080704e-02],
#        [  7.89775178e-02],
#        [  2.11467847e-01],
#        [  2.12375149e-01],
#        [  2.60521710e-01],
#        [  3.63507748e-01],
#        [  2.92526722e-01],
#        [  5.66339009e-02],
#        [  1.82200417e-01],
#        [  1.87443480e-01],
#        [  2.57859100e-02],
#        [  1.50265262e-01],
#        [  1.77273408e-01],
#        [  1.46896437e-01],
#        [  1.27038613e-01],
#        [  5.46161793e-02],
#        [  1.12656884e-01],
#        [  1.75864279e-01],
#        [  1.31325603e-01],
#        [  1.06722526e-01],
#        [  4.86202259e-03],
#        [  8.25867206e-02],
#        [  3.69618028e-01],
#        [  1.34515837e-01],
#        [  3.95820796e-01],
#        [  9.77704581e-03],
#        [  1.01887777e-01],
#        [  7.19589666e-02],
#        [  8.70934203e-02],
#        [  1.71959609e-01],
#        [  1.23991705e-01],
#        [  1.42355755e-01],
#        [  9.45417285e-02],
#        [  2.27314040e-01],
#        [  4.38157231e-01],
#        [  2.89865255e-01],
#        [  1.79297298e-01],
#        [  3.63971084e-01],
#        [  3.89647812e-01],
#        [  2.27921233e-01],
#        [  6.90317526e-02],
#        [  2.26556018e-01],
#        [  9.41259265e-02],
#        [  1.80965126e-01],
#        [  1.89834073e-01],
#        [  2.49971181e-01],
#        [  1.44073084e-01],
#        [  4.09607887e-01],
#        [  8.02216604e-02],
#        [  4.24206197e-01]], dtype=float32)
